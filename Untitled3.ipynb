# %% [markdown]
# **Basic Mathematic code**

# %%
#code for all mathematical calculations
a = 5
b = 23
print("Additon of a & b:", a + b )
print("Subtraction of b & a:", b - a )
print("Multiplication of a & b:", a * b )
print("Division of b & a:", b / a )
# Out:
# Additon of a & b: 28
# Subtraction of b & a: 18
# Multiplication of a & b: 115
# Division of b & a: 4.6

# %%
#code for all mathematical calculations and the varible values are entered by the user
# Taking numeric input
a = int(input("Enter the variable a : "))
b = int(input("Enter the variable b : "))

print("You entered:")
print("A = ", a)
print("B = ", b)

print(f"Addition of a & b: {a + b}")
print(f"Subtraction of a & b: {a - b}")
print(f"Multiplication of a & b: {a * b}")
print(f"Division of a & b: {a / b}")
# Out:
# Enter the variable a : 35
# Enter the variable b : 5
# You entered:
# A =  35
# B =  5
# Addition of a & b: 40
# Subtraction of a & b: 30
# Multiplication of a & b: 175
# Division of a & b: 7.0
